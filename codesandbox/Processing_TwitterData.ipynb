# %% [markdown]
# <a href="https://colab.research.google.com/github/FredLongo/DataMiningProject/blob/main/Processing_TwitterData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Processing File for bringing in data from Twitter that I pulled in using Apify agent.
#
# Reviewing counts and messages.

# %%
import json

# %%
#with open("twiterscraper.json", "r") as f:
with open("/content/dataset_easy-twitter-search-scraper_2023-11-21_01-10-14-456.json", "r") as f:
  data = json.load(f)

# %%
'''
Set up Username Counts
'''

username =["@USNewsMoney", "@TMFStockAdvisor", "@ftfinancenews", "@Stocktwits", "@MadMoneyOnCNBC", "@SquawkCNBC"]

cols = 2
rows = len(username)
username_counts = [[0 for _ in range(cols)] for _ in range(rows)]

# Fill the first column with values from the list
for i in range(rows):
    username_counts[i][0] = username[i]

# Printing the 2D array
#for row in username_counts:    print(row)

# %%
'''
Set up selectQ Counts
'''
searchQuery = ["stock","Apple","Microsoft","Alphabet","Amazon","Nvidia","Tesla","GOOG","AMZN","AAPL","META","MSFT","NVDA","TSLA"]

cols = 2
rows = len(searchQuery)
searchQuery_counts = [[0 for _ in range(cols)] for _ in range(rows)]

# Fill the first column with values from the list
for i in range(rows):
    searchQuery_counts[i][0] = searchQuery[i]

# Printing the 2D array
#for row in searchQuery_counts:

# %%
x_count = 0 #120
user_count = 0   #2900




for x in data:
  x_count+=1

  #get username_counts
  username_counts[username.index(x['user']['username'].rstrip())][1]+=1
  Qu = username_counts[username.index(x['user']['username'].rstrip())][1]

  #get searchQuery_counts
  searchQuery_counts[searchQuery.index(x['searchQuery'].rstrip())][1]+=1
  Qv = searchQuery_counts[searchQuery.index(x['searchQuery'].rstrip())][1]

  print(x_count, x['searchQuery'] ,'=', Qv,x['user']['username'],'=',Qu,'  text:',x['text'])

'''
  Reviewing Data in file
  print('>>>',x_count,'   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
  print('id:',x['id'])
  print('url:',x['url'])
  print('verified:',x['verified'])
  print('timestamp:',x['timestamp'])
  print('text:',x['text'])
  print('links:',x['links'])
  print('isQuote:',x['isQuote'])
  print('isRetweet:',x['isRetweet'])
  print('likes:',x['likes'])
  print('replies:',x['replies'])
  print('retweets:',x['retweets'])
  print('quotes:',x['quotes'])
  print('searchQuery:',x['searchQuery'])
  print('user:',x['user']['username'])
  print('\n\n')
'''
# Out:
# 1 Tesla = 1 @ftfinancenews = 1   text: Supercharged Tesla and Nvidia bets sold through single-stock ETFs on.ft.com/46RVCtc
# 2 Nvidia = 1 @Stocktwits = 1   text: 💻 Just In: $ARM trading higher on news that $NVDA will use their tech to power new Nvidia PC chips.
#
# Key Points:
# • Nvidia & Arm chips could see release as soon as 2025.
# • Arm chips are more power efficient than current generation intel tech.
# 3 AMZN = 1 @Stocktwits = 2   text: Top Trending stocks & crypto on Stocktwits this morning:
#
# 1️⃣ $AMZN
# 2️⃣ $SQ
# 3️⃣ $INTC
# 4️⃣ $F
# 5️⃣ $ENPH
# 6️⃣ $CRSP
# 7️⃣ $SNY
# 8️⃣ $DXCM
# 9️⃣ $ABBV
# 🔟 $CPRX
# 4 MSFT = 1 @Stocktwits = 3   text: Top Trending stocks & crypto on Stocktwits this morning:
#
# 1️⃣ $MARA
# 2️⃣ $DOGE
# 3️⃣ $HARP
# 4️⃣ $MSFT
# 5️⃣ $CVX
# 6️⃣ $FMC
# 7️⃣ $RVMD
# 8️⃣ $HES
# 9️⃣ $PSFE
# 🔟 $ROIV
# 5 NVDA = 1 @Stocktwits = 4   text: Top Trending stocks & crypto on Stocktwits this morning:
#
# 1️⃣ $SPR
# 2️⃣ $UAL
# 3️⃣ $NFLX
# 4️⃣ $NVDA
# 5️⃣ $VKTX
# 6️⃣ $NVAX
# 7️⃣ $PG
# 8️⃣ $MS
# 9️⃣ $ABT
# 🔟 $MRNA
# 6 NVDA = 2 @Stocktwits = 5   text: Top Trending stocks & crypto on Stocktwits this morning:
#
# 1️⃣ $NVDA
# 2️⃣ $LCID
# 3️⃣ $SPRC
# 4️⃣ $BAC
# 5️⃣ $LULU
# 6️⃣ $MRNA
# 7️⃣ $GS
# 8️⃣ $AMD
# 9️⃣ $IWM
# 🔟 $SOXL
# 7 MSFT = 2 @Stocktwits = 6   text: Epic ad from $MSFT 🎮
#
# Which company should use the Sphere next?
# 8 MSFT = 3 @Stocktwits = 7   text: Just In: After 19 months the $MSFT & $ATVI acquisition has been approved by regulators.
#
# Trading of $ATVI has been halted.
# 9 MSFT = 4 @Stocktwits = 8   text: Top Trending stocks & crypto on Stocktwits this evening:
#
# 1️⃣ $TPST
# 2️⃣ $LKNCY
# 3️⃣ $LLY
# 4️⃣ $SPY
# 5️⃣ $MSFT
# 6️⃣ $BIRK
# 7️⃣ $AKRO
# 8️⃣ $REQ
# 9️⃣ $NVO
# 🔟 $HSDT
# 10 NVDA = 3 @Stocktwits = 9   text: Just In: $NVDA offices were raided yesterday by French regulators due to fears of anticompetitive practices.
#
# We'll see how much this matters as $NVDA stock continues to move higher on the day.
# 11 NVDA = 4 @Stocktwits = 10   text: $AMD is trading higher today after Lisa Su made comments saying she's "not a believer in moats."
#
# That quote is creating a lot of drama on our streams.
#
# Are moats real? Do you agree that $NVDA has no AI moat?
# 12 NVDA = 5 @Stocktwits = 11   text: Learn how to separate signal from noise, love this analysis on $NVDA from @DarvasBoxGuru!
# 13 NVDA = 6 @Stocktwits = 12   text: Shoutout $NVDA for saving our portfolios
# 14 TSLA = 1 @Stocktwits = 13   text: $TSLA fighting to hold onto 200 level
# 15 TSLA = 2 @Stocktwits = 14   text: ⚡️Just In: $GM & $HMC scrap plans to co-develop 'affordable' EVs as market demand weakens.
#
# What does this mean for $TSLA?
# 16 TSLA = 3 @Stocktwits = 15   text: $TSLA Place your bets...
# 17 TSLA = 4 @Stocktwits = 16   text: 🔑 $TSLA Key levels to watch:
# 18 TSLA = 5 @Stocktwits = 17   text: Top Trending stocks & crypto on Stocktwits this morning:
#
# 1️⃣ $NFLX
# 2️⃣ $AAL
# 3️⃣ $T
# 4️⃣ $TSLA
# 5️⃣ $TSM
# 6️⃣ $ROKU
# 7️⃣ $ALGO
# 8️⃣ $BEAM
# 9️⃣ $OTMO
# 🔟 $UNP
# 19 Apple = 1 @SquawkCNBC = 1   text: "@Apple made a big point last night to highlight people who are still on @Intel systems which they've been phasing out since 2020," says @joannastern on last night's #AppleEvent. "If you need a new laptop, these are great choices. But you're not upgrading your laptop every year."
# 20 GOOG = 1 @Stocktwits = 18   text: In Today's DailyRip:
#
# Nasdaq 100 Follows Peers Lower
#
# $GOOG posted its worst down day since the start of the pandemic, causing $QQQ to finally break through its Sept. lows. After weeks of bucking the broader weakness, it’s finally “catching down” to the rest of the stock market.
# 21 TSLA = 6 @Stocktwits = 19   text: Top Trending stocks & crypto on Stocktwits this evening:
#
# 1️⃣ $TSLA
# 2️⃣ $NFLX
# 3️⃣ $ROKU
# 4️⃣ $AVXL
# 5️⃣ $ADTX
# 6️⃣ $LRCX
# 7️⃣ $LVS
# 8️⃣ $CCI
# 9️⃣ $ARKK
# 🔟 $CRSP
# 22 TSLA = 7 @Stocktwits = 20   text: ⚡️Tesla stock undisturbed in the after hours following a double miss on their report.
#
# Rev: $23.4B vs $24.06B est.
# EPS: $0.66 vs $0.74 est.
#
# $TSLA +0.5%
# 23 TSLA = 8 @Stocktwits = 21   text: Good Morning!
#
# It's another big day of earnings with financials reporting now and big names, such as $NFLX & $TSLA coming in later tonight.
#
# Here's the earnings action so far from this morning:
#
# $MS 📉
# Rev: $13.27B vs $12.58B est.
# EPS: $1.38 vs $1.22 est.
#
# $USB 📉
# Rev: $7.03B vs $7.02B est.
# Adj. EPS: $1.05 vs $1.02 est.
#
# $ALLY 📉
# Rev: $2.03B vs $2.06B est.
# Adj. EPS: $0.83 vs $0.80 est.
#
# $NTRS 📈
# Rev: $1.74B vs $1.75B est.
# EPS: $1.49 vs $1.47 est.
# 24 TSLA = 9 @Stocktwits = 22   text: Good Morning!
#
# We have an exciting week ahead of us as earnings season gets off the ground.
#
# $TSLA & $NFLX are both set to release reports after market close on Wednesday.
# 25 TSLA = 10 @SquawkCNBC = 2   text: .@DanielTNiles explains why he is shorting $TSLA:
#
# "We think there's a lot of headwinds in the stock. It's done great this year and has pretty high valuation. I don't like companies where numbers are going to have to go down."
# 26 TSLA = 11 @Stocktwits = 23   text: A $TSLA now costs less than the average car 🤯
# 27 TSLA = 12 @Stocktwits = 24   text: When $TSLA originally announced the Model 3, they promised a $35,000 car.
#
# The company is slowly getting back to that target price after announcing further cuts on US prices of Model 3 & Y units.
#
# Current Prices:
# • Model 3 sedan: $38,990
# • Model Y long-range: $48,490
# 28 TSLA = 13 @Stocktwits = 25   text: Top Trending stocks & crypto on Stocktwits this evening:
#
# 1️⃣ $RIVN
# 2️⃣ $LAC
# 3️⃣ $XOM
# 4️⃣ $SAVA
# 5️⃣ $TSLA
# 6️⃣ $NUVL
# 7️⃣ $USO
# 8️⃣ $AMD
# 9️⃣ $ACCD
# 🔟 $AGNC
# 29 TSLA = 14 @Stocktwits = 26   text: Top Trending stocks & crypto on Stocktwits this morning:
#
# 1️⃣ $TSLA
# 2️⃣ $RIVN
# 3️⃣ $BTC
# 4️⃣ $PDSB
# 5️⃣ $RIOT
# 6️⃣ $ETH
# 7️⃣ $COIN
# 8️⃣ $SNDX
# 9️⃣ $SLV
# 🔟 $XPEV
# 30 Tesla = 2 @Stocktwits = 27   text: Tesla has $184 million worth of $BTC on their balance sheet as of Q3.
#
# What are they going to do with it?
# 31 GOOG = 2 @Stocktwits = 28   text: Top Trending stocks & crypto on Stocktwits this morning:
#
# 1️⃣ $MSFT
# 2️⃣ $GOOGL 📉
# 3️⃣ $ASPA
# 4️⃣ $AVXL
# 5️⃣ $SNAP
# 6️⃣ $GOOG
# 7️⃣ $BA
# 8️⃣ $PYPL
# 9️⃣ $TDOC
# 🔟 $PEPE
# 32 stock = 1 @Stocktwits = 29   text: In Today's DailyRip:
#
# October Was As Spooky As Expected
#
# October is seasonally a weak period for the stock market, and this year certainly lived up to that expectation.
# 33 Tesla = 3 @Stocktwits = 30   text: Good Morning!
#
# Tesla is set to open near key levels after dropping in after hours following their lackluster report and comments from Elon that he's worried about the interest rate environment.
#
# $TSLA stock price is breaking down below support that’s been intact since May... 😬
# 34 Apple = 2 @SquawkCNBC = 3   text: Today's #SquawkPod: @WalterIsaacson discusses the tricky terrain for a corporation like @Apple, navigating Chinese and American geopolitics. Plus, Israeli tech entrepreneur Eyal Waldman reflects on the tragic loss of his daughter.
#
# LISTEN: link.chtbl.com/squawk_pod
# 35 Apple = 3 @USNewsMoney = 1   text: In 2023, it's difficult to imagine a world of phones and personal electronic devices that is not dominated by Apple. However, way back in 2003, Apple wasn't even in the smartphone business. money.usnews.com/investing/a…
# 36 Nvidia = 2 @Stocktwits = 31   text: Nvidia stock put on slides this morning after reports drop that the Biden administration is tightening restrictions on China's ability to buy advanced semiconductors.
#
# $NVDA -3.75%
# 37 AMZN = 2 @Stocktwits = 32   text: Top Trending stocks & crypto on Stocktwits this evening:
#
# 1️⃣ $AMZN
# 2️⃣ $ENPH
# 3️⃣ $INTC
# 4️⃣ $F
# 5️⃣ $SOFI
# 6️⃣ $CMG
# 7️⃣ $QQQ
# 8️⃣ $DXCM
# 9️⃣ $CPRX
# 🔟 $MO
# 38 Tesla = 4 @Stocktwits = 33   text: Tesla is trading down today before earnings where the market expects to see an implied move of ~5% following the report.
#
# Here’s a preview of $TSLA’s earnings estimates:
# 39 AMZN = 3 @Stocktwits = 34   text: Amazon delivering good news to bulls as their stock climbs higher off its top and bottom line beat.
#
# Rev: $143.08B vs $141.56B est.
# EPS: $0.94 vs $0.81 est.
#
# $AMZN +3.5% in after-hours trading.
# 40 Apple = 4 @Stocktwits = 35   text: Meta Smart Glasses: $299
# Apple Vision Pro: $3,499
#
# Which are you buying?
# 41 Alphabet = 1 @Stocktwits = 36   text: Alphabet moving lower following disappointing numbers despite a double beat on top and bottom line.
#
# Rev: $64.05B vs $63.04B est.
# EPS: $1.55 vs $1.45 est.
#
# $GOOGL -4.22%
# 42 stock = 2 @Stocktwits = 37   text: Everybody's favorite stock ended up disappointing tonight as stock drops on weak guidance.
#
# Rev: $5.8B vs $5.7B est.
# EPS: $0.70 vs $0.68 est.
#
# Q4 Guidance: $5.8 - $6.4B vs $6.4B est.
#
# $AMD -4.20% in after-hours.
# 43 Alphabet = 2 @MadMoneyOnCNBC = 1   text: .@jimcramer on Tuesday shared his opinions on two antitrust lawsuits involving Amazon and Alphabet-owned Google, arguing that neither company is a true monopoly.
# cnbc.com/2023/09/26/cramer-a…
# 44 AMZN = 4 @Stocktwits = 38   text: Top Trending stocks & crypto on Stocktwits this morning:
#
# 1️⃣ $META
# 2️⃣ $DOGE
# 3️⃣ $AMZN
# 4️⃣ $SAVE
# 5️⃣ $DIA
# 6️⃣ $NOW
# 7️⃣ $VKTX
# 8️⃣ $SPX
# 9️⃣ $UAL
# 🔟 $CMCSA
# 45 Tesla = 5 @SquawkCNBC = 4   text: "The @Tesla Cybertruck is coming, the @Ford next generation Lightning is coming. Is there too much saturation for the electric pickup truck?" @lebeaucarnews asks @Rivian CEO @RJscaringe:
# 46 AMZN = 5 @Stocktwits = 39   text: $AMZN is trading down a bit before their earnings drop after the bell. The market is expecting an implied move of ~6.80% following its report.
#
# Amazon has beat on 3 out if its last 4 reports.
# 47 stock = 3 @Stocktwits = 40   text: Just In: WeWork stock looks like it's finally headed to the grave as the company expects to file for bankruptcy next week.
# 48 Apple = 5 @SquawkCNBC = 5   text: .@Apple's Eddy Cue is set to testify today in the government's antitrust case against $GOOGL. @CNBC's Steve Kovach joins with the latest:
# 49 Apple = 6 @SquawkCNBC = 6   text: The new $AAPL iPhone launches today. Steve Kovach is live at @Apple's New York City store, where CEO Tim Cook greeted fans.
# 50 AMZN = 6 @Stocktwits = 41   text: Top Trending stocks & crypto on Stocktwits this evening:
#
# 1️⃣ $META
# 2️⃣ $DOGE
# 3️⃣ $QS
# 4️⃣ $SAVA
# 5️⃣ $AMZN
# 6️⃣ $SHIB
# 7️⃣ $ASPA
# 8️⃣ $ALGN
# 9️⃣ $ARKK
# 🔟 $NOW
# 51 Tesla = 6 @SquawkCNBC = 7   text: "@elonmusk's presence is looming over the @UAW strike," says @WSJ's @timkhiggins. "From day one, Elon wins because it's cheaper to build a Tesla...It's a race to make electric vehicles profitable and $TSLA is doing that. The likes of Ford are not."
# 52 stock = 4 @Stocktwits = 42   text: Bud Light is winning back some bidders this morning after Anheuser stock gains on mixed results.
#
# Rev: $15.57B vs $15.71B est.
# EPS: $0.86 vs $0.83 est.
#
# $BUD +3.20% in pre-market trading.
# 53 Tesla = 7 @Stocktwits = 43   text: Delivery numbers dropped this morning for both $RIVN & $TSLA:
#
# $TSLA Total Deliveries, 435,059 vs. 456,722 est. (MISS)
# $RIVN  Total Deliveries, 15,564 vs. 14,973 est. (BEAT)
#
# Is Tesla's market dominance up for grabs in the EV space?
# 54 Tesla = 8 @SquawkCNBC = 8   text: "Does automation create more jobs in the aggregate or does it destroy jobs? What we know is it will decimate assembly line worker jobs even if it might lead to a more productive economy," says @WalterIsaacson. "$TSLA is building @Tesla_Optimus."
# 55 Microsoft = 1 @Stocktwits = 44   text: Microsoft ramping in the after hours after posting strong results with a double beat.
#
# Rev: $56.5B vs $54.4B est.
# EPS: $2.99 vs $2.65 est.
#
# $MSFT +5%
# 56 stock = 5 @Stocktwits = 45   text: Caterpillar is perplexing investors this morning as the stock drops following a double beat and raised guidance.
#
# Rev: $16.81B vs $16.53B est.
# EPS: $5.52 vs $4.76 est.
#
# $CAT -4.90% in pre-market trading.
# 57 Apple = 7 @SquawkCNBC = 9   text: "What do you tell @Apple, @Tesla and @Disney when you are proposing a restricted future with China when it's such an important trading partner?" @JoeSquawk asks @Mike_Pence:
# 58 Microsoft = 2 @SquawkCNBC = 10   text: "Once we started to think about how much of an advantage it would be to be a part of @Microsoft, after that we never thought it was anything other than a good idea," says $ATVI CEO @BobbyKotick. "We never thought there was any reason why these two companies couldn't combine."
# 59 AMZN = 7 @SquawkCNBC = 11   text: "I don't believe in the $AMZN case that the Justice Department is going to prevail. @Amazon's got a strong case. The retail market is very competitive," says Barton Crockett. "Our base case when we look at this litigation is that the stocks would probably benefit in a breakup."
# 60 AMZN = 8 @Stocktwits = 46   text: Walmart CEO is eager to compete vs. $AMZN for e-commerce market share.
#
# “Amazon has never been known as the most seller-friendly place to do business... I’ve seen a lot of sellers actually cheering for Walmart because they want an alternative."
#
# This could get spicy 🌶️
# 61 Apple = 8 @SquawkCNBC = 12   text: "It's very hard for me to see that @Apple, for purposes of driving a streaming business, would want to get into declining linear assets or a theme park business," says Tom Rogers on the possibility of $AAPL buying $DIS. "I think that's highly unrealistic."
# 62 Tesla = 9 @SquawkCNBC = 13   text: Today's #SquawkPod: Billionaire investor Ron Baron shares insights on his significant investments in @elonmusk's ventures, including @Tesla and @SpaceX. Plus, Detroit faces a looming auto workers strike and CPI records a 3.7% YoY increase.
#
# LISTEN: link.chtbl.com/squawk_pod
# 63 Tesla = 10 @SquawkCNBC = 14   text: "@elonmusk has a huge competitive advantage at $TSLA in terms of making the EVs. Are you are going to be able to compete on a relative basis with a lean and mean Tesla when you are asking for 40% increase in wages?" @JoeSquawk asks @UAW President Shawn Fain.
# 64 AMZN = 9 @Stocktwits = 47   text: ⚡️Just In: $AMZN says it has 10,000 $RIVN electric vans in its delivery fleet.
#
# Amazon currently has ~100,000 gas vans worldwide, which will be "slowly retired.”
# 65 AAPL = 1 @Stocktwits = 48   text: Great look at $AAPL falling below 200d for first time since March...
# 66 Microsoft = 3 @Stocktwits = 49   text: Satya Nadella, CEO of $MSFT, gave a hard hitting testimony last week on $GOOGL antitrust case.
#
# "Microsoft is trapped in a “vicious cycle” where Google uses its roughly 90% market share to continually improve its search results... which in turn further reinforces its monopoly."
# 67 GOOG = 3 @Stocktwits = 50   text: Huge day of earnings after market close ft. $GOOG, $V, $SNAP, & $MSFT
#
# Here are the implied moves, estimates, and history for each:
# 68 Apple = 9 @USNewsMoney = 2   text: Apple is now the most valuable company in the U.S. market with a market cap of nearly $3 trillion. money.usnews.com/investing/s…
# 69 AAPL = 2 @Stocktwits = 51   text: Top Trending stocks & crypto on Stocktwits heading into the weekend:
#
# 1️⃣ $SOFI
# 2️⃣ $F
# 3️⃣ $SAVA
# 4️⃣ $OSTK
# 5️⃣ $SAVE
# 6️⃣ $ABBV
# 7️⃣ $XBI
# 8️⃣ $CVX
# 9️⃣ $GLD
# 🔟 $AAPL
# 70 GOOG = 4 @Stocktwits = 52   text: Top Trending stocks & crypto on Stocktwits this evening:
#
# 1️⃣ $MSFT
# 2️⃣ $GOOGL
# 3️⃣ $SNAP
# 4️⃣ $GOOG
# 5️⃣ $COIN
# 6️⃣ $TDOC
# 7️⃣ $NIO
# 8️⃣ $V
# 9️⃣ $MARA
# 🔟 $IMGN
# 71 AAPL = 3 @SquawkCNBC = 15   text: "We are barrowing down a road of trying to disengage from China which is not easy to do. And $AAPL will be most hurt," says @WalterIsaacson. "We're going to have to strike some kind of total equilibrium between total disengagement and total dependence."
# 72 stock = 6 @Stocktwits = 53   text: Good Morning & Happy Halloween! 🦇
#
# We decided to scare you today by making you look at Hershey's 6mo stock chart.
#
# This is the one of the worst drawdowns the company has ever experienced as chocolate sales across the U.S. slows.
#
# Is $HSY at these levels a trick or treat?
# 73 Tesla = 11 @SquawkCNBC = 16   text: Today's #SquawkPod: @WalterIsaacson discusses his latest biography on @elonmusk and discusses the purchase of Twitter, a heated exchange between the Tesla CEO and Bill Gates, and what’s behind Musk’s controversial midnight posts on X.
#
# LISTEN: link.chtbl.com/squawk_pod
# 74 Microsoft = 4 @SquawkCNBC = 17   text: .@Microsoft will start selling its new AI tool, Copilot, for $30 a month starting in November. @CNBC's Steve Kovach joins to talk more about the AI-hype:
# 75 AMZN = 10 @Stocktwits = 54   text: Top Trending stocks & crypto on Stocktwits this morning:
#
# 1️⃣ $BNOX (Bitotech runner)
# 2️⃣ $GME
# 3️⃣ $MU
# 4️⃣ $PTON
# 5️⃣ $TLT
# 6️⃣ $AMZN
# 7️⃣ $DWAC
# 8️⃣ $SSYS
# 9️⃣ $CHS
# 🔟 $CCJ
# 76 AMZN = 11 @SquawkCNBC = 18   text: HAPPENING NOW:
# - $AMZN and $MSFT mixed after UK regulators began probing their cloud dominance
# - $XOM shares down despite positive Q3 expectations
# - $RIVN down due to guidance coming in below expectations
#
# @FrankCNBC breaks down this morning's market movers:
# 77 AAPL = 4 @Stocktwits = 55   text: Added $AAPL to watchlist ⌚️
# 78 Tesla = 12 @Stocktwits = 56   text: Tesla stream remains bullish on the stock in spite of recent price action and move lower in pre market.
#
# $TSLA -3%
# 79 AMZN = 12 @SquawkCNBC = 19   text: Today's #SquawkPod: @FTC Chair @LinaKhanFTC joins to discuss the FTC and 17 states filing an antitrust lawsuit against @Amazon. Khan defends the decision, arguing $AMZN has used its dominance to unfairly harm competition.
#
# LISTEN: link.chtbl.com/squawk_pod
# 80 GOOG = 5 @Stocktwits = 57   text: Good Morning!
#
# Earnings season is set to begin its slow ramp-up, as 620 companies report this week.
#
# This week's calendar features: $MSFT, $GOOG, $AMZN, $META, $UPS, $MA, $V, $XOM, $CVX, & $GM.
# 81 stock = 7 @MadMoneyOnCNBC = 2   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Monday, he told one caller to buy Merck.
# cnbc.com/2023/10/30/cramers-…
# 82 GOOG = 6 @Stocktwits = 58   text: Top Trending stocks & crypto on Stocktwits this evening:
#
# 1️⃣ $ALXO
# 2️⃣ $AVXL
# 3️⃣ $ETH
# 4️⃣ $BAD
# 5️⃣ $DPZ
# 6️⃣ $BCRX
# 7️⃣ $AMC
# 8️⃣ $GOOG
# 9️⃣ $MSS
# 🔟 $FUND
# 83 AAPL = 5 @SquawkCNBC = 20   text: HAPPENING NOW:
# - $AAPL shares slip after downgrade by Keybanc
# - $INTC on the rise after plan to spin off programmable chip unit
# - 10-year Treasury yield trades near levels not seen since 2007
#
# @FrankCNBC breaks down this morning's market movers:
# 84 Tesla = 13 @Stocktwits = 59   text: Good Morning and Happy Friday folks!
#
# Bullish energy all over the $TSLA stream today on news that they have cut prices across the board on their products.
#
# How long until every car on the road is a Tesla?
# 85 GOOG = 7 @Stocktwits = 60   text: Top Trending stocks & crypto on Stocktwits this evening:
#
# 1️⃣ $PLUG
# 2️⃣ $NEE
# 3️⃣ $RUN
# 4️⃣ $OXY
# 5️⃣ $MARA
# 6️⃣ $XLU
# 7️⃣ $CRSP
# 8️⃣ $V
# 9️⃣ $GOOG
# 🔟 $ACGL
# 86 AMZN = 13 @SquawkCNBC = 21   text: "Sellers have to inflate their price not just on $AMZN but also across the rest of the internet," says @LinaKhanFTC. "If you had a platform for a retailer that was more efficient, it would not actually be able to compete on price because of @Amazon's anti-discounting tactics."
# 87 stock = 8 @Stocktwits = 61   text: SoFi bulls are getting excited this morning after the stock gaps up following a strong double beat.
#
# Rev: $537.2M vs $515M est.
# EPS: ($0.03) vs ($0.09) est.
#
# $SOFI +7.5% in pre-market trading.
# 88 stock = 9 @ftfinancenews = 2   text: Defined Contribution pensions: the lifestyle you ordered is currently out of stock on.ft.com/3QKXb6N
# 89 AAPL = 6 @SquawkCNBC = 22   text: $AAPL's latest iPhone is on sale today, which comes as the mega-cap tech company faces mounting challenges around demand in China. @neubergerberman's Dan Flax weighs in:
# 90 AAPL = 7 @Stocktwits = 62   text: Just In: $AAPL & $GS were planning on stock-trading feature for iPhones until markets turned last year.
# 91 stock = 10 @MadMoneyOnCNBC = 3   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Friday, he told one caller not to buy General Motors.
# cnbc.com/2023/10/27/cramers-…
# 92 AMZN = 14 @Stocktwits = 63   text: Good Morning!
#
# Major concern is brewing today in big tech following FTC's lawsuit levied against $AMZN.
#
# As a result the “big five” tech giants all traded lower. They’ve been driving the market, so weakness here increases the pressure on an already troubled market...
# 93 AAPL = 8 @SquawkCNBC = 23   text: BREAKING: Sources say that $AAPL and $GS planned to offer stock trading on iPhones, but the plan was put on hold as the stock market went south. @Kr00ney joins with more:
# 94 stock = 11 @USNewsMoney = 3   text: If you'd rather begin building your own stock portfolio from scratch, here are some of the best established stocks to buy with $1,000 that have "buy" ratings from the CFRA Research analyst team. money.usnews.com/investing/a…
# 95 AMZN = 15 @Stocktwits = 64   text: Top Trending stocks & crypto on Stocktwits this morning:
#
# 1️⃣ $LCID
# 2️⃣ $AMZN
# 3️⃣ $LUNC 🥴
# 4️⃣ $NYC
# 5️⃣ $COST
# 6️⃣ $NET
# 7️⃣ $LRE
# 8️⃣ $TGT
# 9️⃣ $BCH
# 🔟 $IONQ
# 96 AMZN = 16 @Stocktwits = 65   text: Top trending stocks on Stocktwits this evening:
#
# 1⃣ $TGT
# 2⃣ $COST
# 3⃣ $SLNO
# 4⃣ $AMZN
# 5⃣ $UVXY
# 97 stock = 12 @ftfinancenews = 3   text: Jamie Dimon to sell JPMorgan stock for first time on.ft.com/45Wg8I0
# 98 stock = 13 @ftfinancenews = 4   text: Comparisons are odious for London’s stock market on.ft.com/3QadWXn
# 99 stock = 14 @Stocktwits = 66   text: Chipotle stock also moving higher following strong results and CEO comments that their, "value proposition is stronger than ever."
#
# Rev: $2.5B vs $2.47B est.
# EPS: $11.36 vs $10.56 est.
#
# $CMG +5.20% in after-hours trading.
# 100 stock = 15 @MadMoneyOnCNBC = 4   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Thursday, he told one caller not to buy HF Sinclair.
# cnbc.com/2023/10/26/cramers-…
# 101 AMZN = 17 @Stocktwits = 67   text: US Government and 17 States sue $AMZN in Landmark Monopoly Case
#
# Key Points:
# • Amazon is accused of unfairly promoting its own platform and services at the expense of 3rd-party sellers
# • Amazon disputes the claim citing their practice has spurred innovation and reduced prices
# 102 stock = 16 @Stocktwits = 68   text: Comcast stock getting sent lower despite a double beat and extremely positive momentum in Universal Studio parks business.
#
# Rev: $30.12B vs $29.17B est.
# EPS: $1.08 vs $0.95 est.
#
# $CMCSA -5.80% in pre-market trading.
# 103 AAPL = 9 @Stocktwits = 69   text: The markets are closed. 🔕
#
# Here are this evening's trending stocks: $AAPL, $WE, $AUPH, $ORCL, & $GCT
# 104 AAPL = 10 @SquawkCNBC = 24   text: $AAPL's annual iPhone event kicks off today. @RBLTSecurities' Barton Crockett has a preview of the event and weighs in on the company's new "made in India" phone.
# 105 AMZN = 18 @Stocktwits = 70   text: Just In: $AMZN plans commercial breaks for Prime Video
#
# Key Points:
# • Benchmark is set for 4 minutes of ads per hour watched
# • You can maintain ad-free viewing by paying an additional $2.99 a month
# 106 AMZN = 19 @Stocktwits = 71   text: The AI hype train continues:
# 1. Wall Street goes all-in on Microsoft's ($MSFT) AI push, as final analyst upgrades stock from sell
# 2. Amazon ($AMZN) invests $4 billion in OpenAI competitor Anthropic
# 3. Getty Images ($GETY) unveils an AI generator that uses only its licensed images
# 107 AMZN = 20 @Stocktwits = 72   text: Top Trending stocks on Stocktwits this evening:
#
# 1️⃣ $LCID
# 2️⃣ $SPY
# 3️⃣ $AMZN
# 4️⃣ $TLT
# 5️⃣ $CCG
# 6️⃣ $BOIL
# 7️⃣ $PYPL
# 8️⃣ $DG
# 9️⃣ $TDOC
# 🔟 $SCHL
# 108 AAPL = 11 @SquawkCNBC = 25   text: HAPPENING NOW:
# - $AAPL falls this week on China iPhone ban concerns
# - $RH posts lower-than-expected guidance
# - $DOCU beats on the top and bottom lines
#
# @FrankCNBC has the #MorningMovers:
# 109 AMZN = 21 @SquawkCNBC = 26   text: This week, the @FTC amped up its lawsuit against $AMZN for making the Prime subscription service too hard to quit. But is it the right battle for regulators to fight? @jonfortt weighs both sides of the argument #OTOH.
# 110 AMZN = 22 @Stocktwits = 73   text: In Today's DailyRip:
#
# Tech Pump Leads Stock Jump
#
# Strength in $TSLA, $AMZN, $META, and several other tech giants helped move the major indexes from a mixed start to a strong close.
# 111 AMZN = 23 @Stocktwits = 74   text: The markets are closed. 🔕
#
# Here are this evenings trending stocks: $NVAX, $AMZN, $RTX, $TSLA, & $BTC.X
# 112 AAPL = 12 @Stocktwits = 75   text: Apple leading the market lower heading into the close.
#
# $AAPL -3.5%
# 113 AAPL = 13 @Stocktwits = 76   text: China Bans IPhone Use for Government Officials at Work
#
# $AAPL -3% today…
# 114 AAPL = 14 @SquawkCNBC = 27   text: .@WaltLightShed is the only analyst on the Street with a sell rating on $AAPL. He defends his thesis:
# 115 stock = 17 @Stocktwits = 77   text: Tractor Supply Co. is the latest company to be impacted by soft guidance as the stock tumbles this morning following their report.
#
# Rev: $3.41B vs $3.47B est.
# EPS: $2.33 vs $2.29 est.
#
# $TSCO -7.15% in pre-market trading.
# 116 stock = 18 @SquawkCNBC = 28   text: HAPPENING NOW:
# - $META stock down after issuing light guidance
# - $IXIC 11% below 52-week high as tech stocks struggle
# - $UPS cuts annual revenue forcast
# - $MRK beats earnings expectations
#
# @TheDomino breaks down this morning's market movers:
# 117 stock = 19 @MadMoneyOnCNBC = 5   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Wednesday, he told one caller he liked Rivian, but it was losing money.
# cnbc.com/2023/10/25/cramers-…
# 118 stock = 20 @Stocktwits = 78   text: It's a good time to be in the semiconductor business.
#
# Japanese semiconductor equipment maker Kokusai Electric just saw a 32% jump in its stock price following its debut on the Tokyo stock exchange.
# 119 stock = 21 @MadMoneyOnCNBC = 6   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Tuesday, he told one caller he liked T-Mobile more than AT&T.
# cnbc.com/2023/10/24/cramers-…
# 120 stock = 22 @MadMoneyOnCNBC = 7   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Monday, he told one caller to sell Fisker.
# cnbc.com/2023/10/23/cramers-…
# 121 AAPL = 15 @SquawkCNBC = 29   text: $AAPL shares were rattled this week on news that China is restricting government employees from using foreign mobile devices, including the iPhone. @Onlyyoontv reports:
# 122 stock = 23 @MadMoneyOnCNBC = 8   text: .@jimcramer said investors shouldn’t read too much into Monday’s stock moves, suggesting more important information will come later in the week.
# cnbc.com/2023/10/23/jim-cram…
# 123 stock = 24 @Stocktwits = 79   text: Disney stock is currently trading near 10 year lows.
#
# If you were CEO of $DIS, what's the first thing you would do to turn the company around?
# 124 stock = 25 @SquawkCNBC = 30   text: BREAKING: $CVX is buying $HES for $53 billion in stock. @BeckyQuick has the details:
# 125 AAPL = 16 @SquawkCNBC = 31   text: $QCOM is announcing it will supply $AAPL iPhone 5G modem chips throughout 2026. @KristinaParts joins with more:
# 126 stock = 26 @USNewsMoney = 4   text: Artificial intelligence can give you an edge if you are looking for a good place to start and want a few stock recommendations. money.usnews.com/investing/a…
# 127 stock = 27 @Stocktwits = 80   text: In Today's DailyRip:
#
# Closed On The Lows
#
# Stock market indexes closed the week on their lows, with the $SPY below its 200d MA for the first time since March. Investors remain hesitant to take on risk ahead of the weekend, with “safe haven” assets like gold catching a bid.
# 128 stock = 28 @SquawkCNBC = 32   text: Stock futures are down as the 10-year Treasury yield crossed 5% for the first time since 2007. @michaelsantoli takes a closer look at the charts:
# 129 stock = 29 @MadMoneyOnCNBC = 9   text: .@jimcramer said it can be easy to get caught up in the hype of a hot stock without fully understanding what the company does and how it turns a profit.
# cnbc.com/2023/06/28/jim-cram…
# 130 stock = 30 @MadMoneyOnCNBC = 10   text: .@jimcramer said investors always need to be prepared for corrections because like rain, they are an inevitable part of life and the stock market.
# cnbc.com/2023/07/03/jim-cram…
# 131 stock = 31 @MadMoneyOnCNBC = 11   text: .@jimcramer said bonds are usually indicative of where the stock market is headed.
# cnbc.com/2023/07/03/jim-cram…
# 132 stock = 32 @MadMoneyOnCNBC = 12   text: .@jimcramer warned investors that panic is neither a helpful emotion nor a proper strategy on the stock market.
# cnbc.com/2023/06/29/jim-cram…
# 133 stock = 33 @MadMoneyOnCNBC = 13   text: .@jimcramer said one of the keys to having a successful stock portfolio is to always do the research.
# cnbc.com/2023/06/29/jim-cram…
# 134 AAPL = 17 @Stocktwits = 81   text: $AAPL strategy meeting ahead of #AppleEvent
# 135 AAPL = 18 @Stocktwits = 82   text: Where would $AAPL stock price be if Steve Jobs was still CEO?
# 136 Apple = 10 @SquawkCNBC = 33   text: "Given that the Yuan had weakened, that would have pointed to the fact that @Apple would have raised the #iPhone price in China. It did not," says Bernstein's Toni Sacconaghi. "That might be a reflection that the Chinese smartphone market is pretty tough right now."
# 137 Apple = 11 @SquawkCNBC = 34   text: "Will @Apple's switch to USB-C lead to a loss of revenue?" @andrewrsorkin asks Bernstein's Toni Sacconaghi:
# 138 Apple = 12 @SquawkCNBC = 35   text: $AAPL announced the iPhone 15 line of phones complete with USB-C charging, as well a new Apple Watch and updated AirPods yesterday at its product launch event. Steve Kovach and @JoannaStern breakdown the highlights:
# 139 Apple = 13 @Stocktwits = 83   text: In Today's DailyRip:
#
# Tech Backtracks Before Inflation Data
#
# Tesla could not save the Nasdaq today, with weakness from Apple, Oracle, and Microsoft dragging stocks lower ahead of tomorrow’s inflation print.
# 140 Apple = 14 @MadMoneyOnCNBC = 14   text: .@jimcramer on Tuesday told investors he thinks fear, not any valid reason, is causing tech stocks like Oracle and Apple to fall.
# cnbc.com/2023/09/12/-cramer-…
# 141 AAPL = 19 @Stocktwits = 84   text: Good Morning!
#
# All eyes are on Apple today as it continues to sell off before the open following news that China plans on extending its ban of the iPhone to more government positions.
#
# $AAPL -3% pre market
# 142 Apple = 15 @Stocktwits = 85   text: Our reaction when Apple releases the same phone for another year at #AppleEvent
# 143 Apple = 16 @Stocktwits = 86   text: Good Morning!
#
# Apple will be the big player in focus today as they unveil the new iPhone 15 and more during their 'Wonderlust' event that begins today at 1PM EST.
#
# Raise your hand if you're going to be buying the new iPhone ✋
# 144 Apple = 17 @Stocktwits = 87   text: Apple's YouTube stream of #AppleEvent  is receiving a surprising amount of 'Dislikes' relative to 'Likes'
# 145 NVDA = 7 @SquawkCNBC = 36   text: $INTC fell this week on news that $NVDA plans to compete in CPU chips, sparking concerns that new rivals with ARM designs could hamper Intel's turnaround efforts. Is @Intel in trouble? @jonfortt weighs in...twice #OTOH:
# 146 NVDA = 8 @Stocktwits = 88   text: $NVDA CEO on if he would start the company over again:
#
# “I wouldn’t do it.”
# 147 MSFT = 5 @SquawkCNBC = 37   text: "Do the concessions make it a less competitive company?" @BeckyQuick asks $ATVI CEO @BobbyKotick after closing a deal with $MSFT.
#
# "They've given up a lot but I think it will encourage competition."
# 148 Apple = 18 @SquawkCNBC = 38   text: China's cyber watchdog is tightening the leash on app stores, with @Apple yet to comply. @onlyyoontv joins live from Beijing:
# 149 MSFT = 6 @SquawkCNBC = 39   text: $MSFT CEO @satyanadella is set to testify today in $GOOGL's antitrust trial. @eamonjavers joins with the latest:
# 150 GOOG = 8 @Stocktwits = 89   text: Good Morning!
#
# It was a tale of two cloud businesses last night as $GOOG & $MSFT diverged following ERs.
#
# The generative AI-focused platform on Microsoft's cloud continues to impress customers where as Google's "third rate" cloud biz disappoints.
#
# 📈 $MSFT +3.75%
# 📉 $GOOG -5.90%
# 151 NVDA = 9 @SquawkCNBC = 40   text: HAPPENING NOW:
# - $RIVN shares up after upgrade to "outperform" by Evercore
# - $NVDA added to Goldman Sachs' conviction list
# - $FDX slightly up after upgrade from Susquehanna
#
# @FrankCNBC breaks down this morning's market movers:
# 152 stock = 34 @Stocktwits = 90   text: $NVDA caught in a bear market?
#
# The stock is now down 20% from its recent highs.
# 153 NVDA = 10 @Stocktwits = 91   text: Top Trending stocks & crypto on Stocktwits this evening:
#
# 1️⃣ $AMD 🔥
# 2️⃣ $FSLR
# 3️⃣ $PAYC
# 4️⃣ $CRSP
# 5️⃣ $CELH
# 6️⃣ $MTCH
# 7️⃣ $CZR
# 8️⃣ $CAT
# 9️⃣ $NVDA
# 🔟 $LTHM
# 154 MSFT = 7 @SquawkCNBC = 41   text: HAPPENING NOW:
# - $MCD to raise royalty fees for newly franchised restaurants
# - UK regulators signal openness to $MSFT-$ATVI merger
# - Recent IPOs $ARM $CART $KVYO still above offering prices
#
# @TheDomino has the #MorningMovers:
# 155 stock = 35 @Stocktwits = 92   text: Pinterest stock pops following strong top and bottom line beat with an 8% YoY increase in MAUs to 482M.
#
# Rev: $763M vs $743.4M est.
# EPS: $0.28 vs $0.20 est.
#
# $PINS +9.15% in after-hours trading.
# 156 NVDA = 11 @SquawkCNBC = 42   text: "I feel that there's been a loss of momentum more broadly for the tech space that includes $NVDA," says @StocktonKatie. "We feel that we would hold existing long positions but not adding exposure until we feel convinced that the corrective phase of the market is over."
# 157 META  = 1 @USNewsMoney = 5   text: When Facebook announced a corporate name change to Meta Platforms Inc. (ticker: META) in October 2021, many investors began to realize just how transformative the metaverse could be. These are the best metaverse stocks to buy today. money.usnews.com/investing/a…
# 158 MSFT = 8 @SquawkCNBC = 43   text: HAPPENING NOW:
# - $ATVI purchase by $MSFT cleared by UK regulators
# - $BLK earnings top estimates-
#  $UNH shares on the rise after positive earnings report
#
# @TheDomino breaks down this morning's market movers:
# 159 META  = 2 @Stocktwits = 93   text: Good Morning!
#
# The market has turned on $META overnight and is sending futures lower after their CFO comments on geopolitical risk effecting ad spend:
#
# "While we don't have direct exposure to Israel and the Middle East, we have observed softer ad spend in the beginning of Q4."
# 160 META  = 3 @Stocktwits = 94   text: Meta whipsawing around to the upside after dropping a top and bottom line beat.
#
# Rev: $34.15B vs $33.52B est.
# EPS: $4.39 vs $3.63 est.
#
# $META +5.05% in after hours trading.
# 161 META  = 4 @Stocktwits = 95   text: $META 🤨
# 162 META  = 5 @Stocktwits = 96   text: Levels to watch for $META earnings 👇
# 163 META  = 6 @Stocktwits = 97   text: $META is trading lower today before their report, which is set to come in after the close with an implied move of ~7.5%.
#
# The company has beat on 2 out of their last 4 reports.
# 164 META  = 7 @Stocktwits = 98   text: Both $META & $GOOGL are making new 52 week highs today 📈
# 165 META  = 8 @Stocktwits = 99   text: Top Trending stocks & crypto on Stocktwits this morning:
#
# 1️⃣ $NVAX
# 2️⃣ $BOIL
# 3️⃣ $CDT
# 4️⃣ $FRLN
# 5️⃣ $LAC
# 6️⃣ $PLTR
# 7️⃣ $UNG
# 8️⃣ $OKTA
# 9️⃣ $META
# 🔟 $SQ
# 166 META  = 9 @Stocktwits = 100   text: Have to give some props to $META on their metaverse progress 👏
# 167 META  = 10 @Stocktwits = 101   text: In Today's DailyRip:
#
# Tech Checked During Meta Connect
#
# Strength in industrial and energy stocks helped push small-caps strongly higher. Meanwhile, the $SPY and $QQQ experienced more volatility during day one of Meta’s “Connect” event before turning green on a late-day rally.
# 168 META  = 11 @Stocktwits = 102   text: These $META Smart Glasses look insane! They can essentially let you Google anything you are looking at.
# 169 META  = 12 @Stocktwits = 103   text: Top Trending stocks & crypto on Stocktwits this evening:
#
# 1️⃣ $MU
# 2️⃣ $META
# 3️⃣ $LRE
# 4️⃣ $XOM
# 5️⃣ $TRB
# 6️⃣ $ACAD
# 7️⃣ $NEE
# 8️⃣ $SLNO
# 9️⃣ $ATLX
# 🔟 $CNXC
# 170 META  = 13 @Stocktwits = 104   text: Meta was the last of the "MAG7" stocks to hold strong for this week.
#
# All it took was for Zuck to begin speaking at their 'Meta Connect' event to send the stock lower.
#
# $META is currently down 2.75% on the day.
# 171 META  = 14 @ftfinancenews = 5   text: Meta pays £149mn to break London office lease on.ft.com/3rrdMlY
# 172 META  = 15 @Stocktwits = 105   text: Top Trending stocks on Stocktwits this morning:
#
# 1️⃣ $CCG
# 2️⃣ $CETX
# 3️⃣ $MLGO
# 4️⃣ $META
# 5️⃣ $YANG
# 6️⃣ $INDI
# 7️⃣ $ATVI
# 8️⃣ $ACH.X
# 9️⃣ $BYND
# 🔟 $LUNC.X
# 173 MSFT = 9 @SquawkCNBC = 44   text: "I am excited that lawmakers want to learn. It's super tough to regulate. So the question is is what kind of responsibility do you force onto the companies," says Fmr. $MSFT CEO @Steven_Ballmer on AI. "I'm totally jumping out of my chair about what's possible with AI."
# 174 Apple = 19 @SquawkCNBC = 45   text: "If @Apple is able to straddle this delicate line between Beijing and Washington, and add value to their economies, I think they're going to be able to do that," says @NeubergerBerman's Dan Flax. "I worry more about their ability to innovate and execute on the product cycles."
# 175 Apple = 20 @MadMoneyOnCNBC = 15   text: .@jimcramer told investors not to sell Apple, saying he has confidence the company will adapt even if China has banned iPhones for its government employees.
# cnbc.com/2023/09/07/cramer-s…
# 176 Apple = 21 @Stocktwits = 106   text: In Today's DailyRip:
#
# Apple Leads Tech Lower
#
# Technology shares continued to lead the market’s weakness, while defensive sectors like utilities and healthcare caught a bid.
# 177 TSLA = 15 @SquawkCNBC = 46   text: "Where is the world going when it comes to transportation? If it's not an electric world, then $TSLA's not going to get there. If it is, then the company is in a great position," says @munster_gene. "@Telsa's got a pole position. Other automotive makers are backing off on EVs."
# 178 TSLA = 16 @Stocktwits = 107   text: What's the one EV company you would invest in that isn't $TSLA?
# 179 TSLA = 17 @Stocktwits = 108   text: As the entire market sells off post FOMC, we're paying close attention to the $TSLA price action.
#
# So far, this trendline remains undefeated.
# 180 TSLA = 18 @SquawkCNBC = 47   text: HAPPENING NOW:
# - $ORCL misses on revenues, posts disappointing forecast
# - $TSLA pulls back after @MorganStanley upgrade-fueled surge
# - $CVS upgraded to buy at Wolfe Research
#
# @TheDomino has the #MorningMovers:
# 181 TSLA = 19 @Stocktwits = 109   text: What’s a worse experience, being short $TSLA or being a Jets fan?
# 182 TSLA = 20 @Stocktwits = 110   text: Fisker moving up 6% today as $TSLA lifts markets higher.
#
# Which stock would you rather own for the long term?
# 183 TSLA = 21 @Stocktwits = 111   text: $TSLA leading the market higher as it climbs up to nearly +10% on the day.
# 184 TSLA = 22 @Stocktwits = 112   text: What will be the price of $TSLA stock at the end of this year?
# 185 TSLA = 23 @Stocktwits = 113   text: Good Morning!
#
# Big move today from $TSLA following upgrade news from $MS that sees the stock at $400 due to their AI capabilities.
#
# $TSLA +6% pre market
# 186 TSLA = 24 @SquawkCNBC = 48   text: HAPPENING NOW:
# - $TSLA upgraded to overweight at @MorganStanley
# - $SJM nears deal to buy $TWNK
# - $ORCL higher ahead of Q1 report
#
# @TheDomino has the #MorningMovers:
# 187 TSLA = 25 @Stocktwits = 114   text: Honda is the latest company to announce it will use $TSLA EV charging ports.
# 188 stock = 36 @Stocktwits = 115   text: 📈 People are still addicted to Netflix apparently as the stock pops following a mixed report.
#
# Rev: $8.54B vs $8.53B est.
# EPS: $2.15 vs $2.17 est.
#
# $NFLX +9.30%
# 189 stock = 37 @MadMoneyOnCNBC = 16   text: .@jimcramer reflected on his flawed prediction for Silicon Valley Bank in which he recommended the stock shortly before the bank failed.
# cnbc.com/2023/10/17/jim-cram…
# 190 stock = 38 @Stocktwits = 116   text: In Today's DailyRip:
#
# Bonds Break To Fresh Lows
#
# It was another mixed session for the stock market as earnings again took center stage. Meanwhile, better-than-expected economic data pushed two and five-year treasuries to fresh lows, with the rest of the curve not far behind.
# 191 stock = 39 @Stocktwits = 117   text: Looks like the market expected more out of United Airlines as the stock drops despite a double beat.
#
# Rev: $14.48B vs $14.42B est.
# Adj. EPS: $3.65 vs $3.34 est.
#
# $UAL -5.04%
# 192 stock = 40 @Stocktwits = 118   text: Lockheed stock moves lower despite a double beat on their ER this morning.
#
# REV: $16.9B vs $16.7B est.
# EPS: $6.73 vs $6.62 est.
#
# $LMT -2.36% in pre-market trading.
# 193 stock = 41 @ftfinancenews = 6   text: EQT testing private stock sales as IPO markets ‘dysfunctional’ on.ft.com/48Zmw3V
# 194 stock = 42 @Stocktwits = 119   text: VinFast is down 18% today following comments from their CEO who expects the need to “tap a lot of capital” in order to fuel geographic expansion.
#
# $VFS could be heading to penny stock status if it breaks below its $6.50 support level.
# 195 stock = 43 @Stocktwits = 120   text: Snapchat stock coming back to life today as the company attempts to leverage generative AI to transform their lenses experience and bolster content creation.
#
# $SNAP +11.5%
# 196 stock = 44 @Stocktwits = 121   text: MEME STOCK WATCH 👀
#
# Rite Aid has just opened trading this morning after announcing bankruptcy over the weekend.
#
# Here's why investors think $RAD could be setting themselves up for a meme stock run:
# • An iconic brand/company
# • High short interest
# • A catalyst (bankruptcy)
# 197 stock = 45 @SquawkCNBC = 49   text: The stock market's relationship to bonds has diverted in recent months. @michaelsantoli takes a closer look at the charts:
# 198 stock = 46 @Stocktwits = 122   text: Just In: Manchester United stock is tumbling this morning after potential whole sale buyers for the business step out while others seek to buy percentage stakes at reduced valuation.
#
# $MANU -11% in pre-market trading.
# 199 stock = 47 @ftfinancenews = 7   text: Stock lending weakens BoJ’s ETF buying programme, BIS paper claims on.ft.com/3FgzZ9V
# 200 stock = 48 @MadMoneyOnCNBC = 17   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Friday, he told one caller to buy Energy Transfer.
# cnbc.com/2023/10/13/cramers-…
# 201 stock = 49 @Stocktwits = 123   text: Not even Taylor Swift could stop AMC from giving all their recent gains back after stock hit resistance today.
#
# $AMC -12% 🍿
# 202 stock = 50 @MadMoneyOnCNBC = 18   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Thursday, he told one caller to sell Phathom Pharmaceuticals.
# cnbc.com/2023/10/12/cramers-…
# 203 stock = 51 @Stocktwits = 124   text: Just In: Dollar General stock jumps in after hours on news that it's bringing back former CEO.
#
# $DG +7.3%
# 204 stock = 52 @SquawkCNBC = 50   text: .@Birkenstock stumbled in its first day of trade. Meanwhile shoe giant @Nike has languished lately, losing half its value since two years ago. Which shoe stock is more likely to go on a run from here: $BIRK or $NKE? @jonfortt weighs in...twice #OTOH
# 205 META  = 16 @Stocktwits = 125   text: Top Trending stocks on Stocktwits this morning:
#
# 1️⃣ $AUPH
# 2️⃣ $DTOC
# 3️⃣ $SPLK
# 4️⃣ $MURF
# 5️⃣ $NEPT
# 6️⃣ $UPTD
# 7️⃣ $AMD
# 8️⃣ $TLT
# 9️⃣ $META
# 🔟 $CSCO
# 206 stock = 53 @ftfinancenews = 8   text: SEC poised to shine light on short selling with stock loan disclosure on.ft.com/3rTpAh1
# 207 stock = 54 @ftfinancenews = 9   text: Beijing fund buys China bank shares in show of support for stock market on.ft.com/3rGa4oX
# 208 stock = 55 @MadMoneyOnCNBC = 19   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Wednesday, he told one caller he wasn't a fan of Plug Power.
# cnbc.com/2023/10/11/cramers-…
# 209 stock = 56 @MadMoneyOnCNBC = 20   text: .@jimcramer on Wednesday said many on Wall Street are already anticipating the impact of GLP-1 drugs, sending down the stock of certain companies, like those involved with diabetes management.
# cnbc.com/2023/10/11/jim-cram…
# 210 stock = 57 @Stocktwits = 126   text: In Today's DailyRip:
#
# Buyers Bypass Birkenstock IPO
#
# The stock market indexes continued their winning streak, but buyers remained wary of this season’s latest initial public offering (IPO), Birkenstock.
# 211 stock = 58 @USNewsMoney = 6   text: Growth funds provide a streamlined avenue for individual investors to gain exposure to a basket of growth stocks without having to pick each stock themselves. money.usnews.com/investing/a…
# 212 stock = 59 @ftfinancenews = 10   text: European investors count the cost of US ‘meme stock’ clean-up on.ft.com/45sL9D9
# 213 stock = 60 @MadMoneyOnCNBC = 21   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Tuesday, he told one caller he was moving on from Herbalife.
# cnbc.com/2023/10/10/cramers-…
# 214 stock = 61 @Stocktwits = 127   text: Groupon stock is having a 25% off sale today, no membership required
# 215 stock = 62 @Stocktwits = 128   text: Good Morning!
#
# The war that erupted over the weekend inevitably led to a knee-jerk reaction in several assets.
#
# The biggest stock moves so far include aerospace & defense, energy, and cyber industries. Meanwhile, airlines fell as flights throughout the region are put on hold.
# 216 stock = 63 @SquawkCNBC = 51   text: HAPPENING NOW:
# - $PEP's Q3 results top analyst estimates
# - $EA stock jumps after upgrade at BofA
# - Calmer trading for energy and defense stocks after surge yesterday
#
# @TheDomino breaks down this morning's market movers:
# 217 stock = 64 @MadMoneyOnCNBC = 22   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Monday, he told one caller Veeva was a buy.
# cnbc.com/2023/10/09/cramers-…
# 218 stock = 65 @MadMoneyOnCNBC = 23   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Friday, he told one caller not to go for Blackstone.
# cnbc.com/2023/10/06/cramers-…
# 219 stock = 66 @MadMoneyOnCNBC = 24   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Thursday, he told one caller he liked Vertex.
# cnbc.com/2023/10/05/cramers-…
# 220 stock = 67 @Stocktwits = 129   text: The onset of ChatGPT and other AI tools has been devastating for the 'Homework Helper' company $CHGG.
#
# The stock is currently trading near all time lows after dropping more than 60% over the last year.
#
# What's the best cast scenario for $CHGG?
# 221 stock = 68 @MadMoneyOnCNBC = 25   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Wednesday, he told one caller Upstart was risky.
# cnbc.com/2023/10/04/cramers-…
# 222 stock = 69 @MadMoneyOnCNBC = 26   text: Despite several weeks of a down market, @jimcramer said Wednesday he sees conditions that could spur a stock market rally.
# cnbc.com/2023/10/04/cramer-p…
# 223 stock = 70 @Stocktwits = 130   text: Rivian stock is moving higher today following CEO comments that they have a "Very Clear" path to profitability.
#
# $RIVN +7.2%
# 224 stock = 71 @Stocktwits = 131   text: $PENN is trending and getting crushed again today.
#
# The stock is now down 23% since they sold Barstool back to @stoolpresidente for $1
# 225 stock = 72 @Stocktwits = 132   text: The stock is *only* down 99% from its all time highs 😅
# 226 stock = 73 @SquawkCNBC = 52   text: Is the stock market oversold? @michaelsantoli breaks down the charts:
# 227 stock = 74 @MadMoneyOnCNBC = 27   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed.
# cnbc.com/2023/10/03/cramers-…
# 228 stock = 75 @MadMoneyOnCNBC = 28   text: .@jimcramer on Tuesday emphasized the importance of the bond market in relation to the stock market, telling investors that stocks are currently at the mercy of bonds.
# cnbc.com/2023/10/03/jim-cram…
# 229 stock = 76 @Stocktwits = 133   text: Impressive relative strength this morning out of $NFLX.
#
# It's the only MAG7 stock that is green today.
# 230 stock = 77 @MadMoneyOnCNBC = 29   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Monday, he told one caller to stay away from PacWest Bancorp.
# cnbc.com/2023/10/02/cramers-…
# 231 stock = 78 @Stocktwits = 134   text: Did you know you can invest in the Las Vegas Sphere?
#
# Sphere Entertainment Co. is part of James Dolan's real-estate empire and is publicly traded under ticker $SPHR.
#
# The stock is up over 100% YTD...
# 232 stock = 79 @SquawkCNBC = 53   text: More #SquawkPod: @GameStop activist @ryancohen is becoming the retailer’s CEO, nearly three years after the “Meme Stock Mania." Author @BenMezrich remembers fondly the $GME craze and the story in the new movie “Dumb Money,” The Antisocial Network.
#
# LISTEN: link.chtbl.com/squawk_pod
# 233 stock = 80 @MadMoneyOnCNBC = 30   text: .@jimcramer on Friday told investors not to make any major stock moves right before a company’s quarterly report.
# cnbc.com/2023/09/29/cramer-s…
# 234 stock = 81 @MadMoneyOnCNBC = 31   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Friday, he told one caller Caterpillar was a buy.
# cnbc.com/2023/09/29/cramers-…
# 235 stock = 82 @Stocktwits = 135   text: Netflix stock is up 31,000% since their IPO in 2002.
#
# Pay your respects to the iconic red envelopes 💿🫡
# 236 stock = 83 @MadMoneyOnCNBC = 32   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Thursday, he told one caller to buy G.E. Healthcare.
# cnbc.com/2023/09/28/cramers-…
# 237 stock = 84 @MadMoneyOnCNBC = 33   text: .@jimcramer suggested the stock market could be headed toward a rally.
# cnbc.com/2023/09/28/jim-cram…
# 238 stock = 85 @Stocktwits = 136   text: Nike stock moving higher after dropping a mixed report at the close.
#
# Revs: $12.94B vs $12.99B est.
# EPS: $0.94 vs $0.75 est.
#
# $NKE +1.30% in after hours
# 239 stock = 86 @MadMoneyOnCNBC = 34   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Wednesday, he told one caller he liked Powell Industries.
# cnbc.com/2023/09/27/cramers-…
# 240 stock = 87 @Stocktwits = 137   text: Micron stock acting fickle after market close going green to red following a double beat on their report.
#
# Rev: $4.01B  vs  $3.91B est.
# EPS: ($1.07)  vs  ($1.18) est.
#
# $MU -2% in after hours trading
# 241 stock = 88 @Stocktwits = 138   text: Ticker $NYC is a New York Real-Estate REIT that owns a portfolio of high-quality commercial real estate.
#
# The stock is experiencing crazy volatility today after it was announced Bellevue Capital Partners launched a tender offer for shares of $NYC priced at $10.25/shr.
# 242 stock = 89 @MadMoneyOnCNBC = 35   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Tuesday, he told one caller he liked Boston Scientific.
# cnbc.com/2023/09/26/cramers-…
# 243 stock = 90 @MadMoneyOnCNBC = 36   text: .@jimcramer tied the stock market’s weakness to the increasing competition offered by U.S. government bonds.
# cnbc.com/2023/09/26/cramer-s…
# 244 stock = 91 @Stocktwits = 139   text: In Today's DailyRip:
#
# Big Tech’s Potential Breakup
#
# Stock market investors went to a dark place as they imagined a world where big tech companies are forced to break up. Additionally, growing worries about the global economy added to the negative sentiment.
# 245 stock = 92 @Stocktwits = 140   text: Congrats to all the Fisker believers today! ⚡
#
# $FSR stock is up 16% today after they hit their production goal of 5,000 Fisker Ocean units.
# 246 stock = 93 @Stocktwits = 141   text: Is there any hope left for $SNAP?
#
# Snapchat started trading at $24 a share when the company IPO'd in March 2017.
#
# The stock is now priced at $8.60 this morning following  another analyst downgrade and is down a whopping  -65% since going public.
# 247 stock = 94 @SquawkCNBC = 54   text: Is the stock market back on its heels after the move in treasury yields? @michaelsantoli takes a closer look at the charts:
# 248 stock = 95 @Stocktwits = 142   text: Welcome to the Weekend Rip!
#
# The stock market had its worst week since March as investors adjusted to the idea that interest rates would likely be higher for longer than anticipated.
#
# Here’s an overview of important earnings and economic data for the trading week ahead:
# 249 stock = 96 @Stocktwits = 143   text: What's a stock market cheat code?
# 250 stock = 97 @MadMoneyOnCNBC = 37   text: .@jimcramer rings the lightning round bell, which means he’s giving his answers to callers’ stock questions at rapid speed. On Friday, he told one caller he liked Confluent.
# cnbc.com/2023/09/22/cramers-…
# 251 stock = 98 @Stocktwits = 144   text: Which stock are you buying that will let you retire in the next 5 years?
# 252 stock = 99 @Stocktwits = 145   text: Top trending stock this morning $SPRY is selling off at record levels after FDA issues the company a surprise complete response letter.
#
# $SPRY -55% in pre-market trading.
# 253 stock = 100 @Stocktwits = 146   text: Good Morning!
#
# Today's spotlight is on the circuit design company 'Arm' as it sets its IPO prices at $51 per share, valuing company at over $54 billion
#
# The stock officially begins trading today and already has 2.5k+ watchers on ST.
#
# Is $ARM's IPO about to flop or moon?
# "\n  Reviewing Data in file\n  print('>>>',x_count,'   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>')\n  print('id:',x['id'])\n  print('url:',x['url'])\n  print('verified:',x['verified'])\n  print('timestamp:',x['timestamp'])\n  print('text:',x['text'])\n  print('links:',x['links'])\n  print('isQuote:',x['isQuote'])\n  print('isRetweet:',x['isRetweet'])\n  print('likes:',x['likes'])\n  print('replies:',x['replies'])\n  print('retweets:',x['retweets'])\n  print('quotes:',x['quotes'])\n  print('searchQuery:',x['searchQuery'])\n  print('user:',x['user']['username'])\n  print('\n\n')\n"

# %%
for row in searchQuery_counts:
    print(row)

print("\n")

for row in username_counts:
    print(row)
# Out:
# ['stock', 100]
# ['Apple', 21]
# ['Microsoft', 4]
# ['Alphabet', 2]
# ['Amazon', 0]
# ['Nvidia', 2]
# ['Tesla', 13]
# ['GOOG', 8]
# ['AMZN', 23]
# ['AAPL', 19]
# ['META', 16]
# ['MSFT', 9]
# ['NVDA', 11]
# ['TSLA', 25]
#
#
# ['@USNewsMoney', 6]
# ['@TMFStockAdvisor', 0]
# ['@ftfinancenews', 10]
# ['@Stocktwits', 146]
# ['@MadMoneyOnCNBC', 37]
# ['@SquawkCNBC', 54]
